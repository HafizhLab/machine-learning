# %% [markdown]
# # Load Corpus

# %%
with open('alquran_korpus.txt') as f:
    ayahs = f.readlines()

# %% [markdown]
# # Sambung Kata

# %%
from lm.markovchain import MarkovChain

# load model
model = MarkovChain()

# train
for ayah in ayahs:
    model.add_document(ayah)

# %%
# test model وَاللَّهُ
model.next_word(input())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-17ab9d765ec7> in <module>
#       1 # test model وَاللَّهُ
# ----> 2 model.next_word(input())
#
# ~/Documents/punya-ima/HafizhLab/machinelearning/lm/markovchain.py in next_word(self, string)
#      91     def next_word(self, string, p=3):
#      92         # Generate next word prediction
# ---> 93         if len(self.lookup_dict) > 0:
#      94             tokens = self._preprocess(string)
#      95
#
# ~/Documents/punya-ima/HafizhLab/machinelearning/lm/markovchain.py in oneword(self, string)
#      64
#      65     def oneword(self, string, p):
# ---> 66         # Find next word given one word known, string is tokenized
#      67         print(string)
#      68         print(Counter(self.lookup_dict[string]))
#
# TypeError: unhashable type: 'list'

# %%
# test model وَاللَّهُ بِمَا تَعْمَلُونَ
model.next_word(input())
# Out:
# [('خَبِيرٌ', 7), ('بَصِيرٌ', 6), ('عَلِيمٌ', 2)]
